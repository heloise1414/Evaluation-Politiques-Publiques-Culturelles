# %% [markdown]
# # Statistiques descriptives et visualisation

# %%
import pandas as pd
from functions import *

# %% [markdown]
# ## Base de données
#
# Tout d'abord, nous récupérons la base de données créée dans le fichier data.ipynb.
#
# Voici ensuite un tableau récapitulatif des variables disponibles dans la base df_final.

# %%
df_final = importdata("df_final.csv", ",")

# %% [markdown]
# <table>
#   <caption>
#     Variables de la base df_final
#   </caption>
#   <thead>
#     <tr>
#       <th scope="col">Nom</th>
#       <th scope="col">Type</th>
#       <th scope="col">Unité</th>
#       <th scope="col">Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th scope="row">code_insee</th>
#       <td>str</td>
#       <td>///</td>
#       <td>Code INSEE du département</td>
#     </tr>
#     <tr>
#       <th scope="row">departement</th>
#       <td>str</td>
#       <td>///</td>
#       <td>Nom du département</td>
#     </tr>
#     <tr>
#       <th scope="row">region</th>
#       <td>str</td>
#       <td>///</td>
#       <td>Région du département</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_biblio</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de bibliothèques dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_ctr_cul</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de centres culturels dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_ctr_art</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de centres artistiques dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_ctr_crea_art</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de centres de création artistique dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_ctr_crea_mus</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de centres de création musicale dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_cine</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de cinémas dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_conserv</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de conservatoires dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_esp_prot</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre d'espaces protégés dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_libr</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de librairies dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_lieu_archeo</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de lieux archéologiques dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_lieu_mem</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de lieux de mémoire dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_monum</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de monuments dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_musee</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de musées dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_opera</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre d'opéras dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_papet</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de papetteries</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_parc_jard</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de parcs et de jardins dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_scene</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de scènes dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_serv_arch</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de services d'archives dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_theatre</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre de théâtres dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_etab_ens_sup</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre d'établissements d'enseignement supérieur dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_ecrans_total</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre total d'écrans de cinéma/de salles de cinéma dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_salles_theatre_total</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre total de salles de théâtre dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_total_etablissements</th>
#       <td>float64</td>
#       <td>Pour 10000 habitants</td>
#       <td>Nombre total d'établissements culturels dans le département pour 10000 habitants</td>
#     </tr>
#     <tr>
#       <th scope="row">nb_jeunes</th>
#       <td>float64</td>
#       <td>Nombre de jeunes</td>
#       <td>Nombre de jeunes dans le département</td>
#     </tr>
#     <tr>
#       <th scope="row">pop_total</th>
#       <td>float64</td>
#       <td>Nombre de personnes</td>
#       <td>Nombre d'habitants dans le départemen</td>
#     </tr>
#     <tr>
#       <th scope="row">rev_median</th>
#       <td>float64</td>
#       <td>Euros annuel</td>
#       <td>Revenu médian dans le département</td>
#     </tr>
#     <tr>
#       <th scope="row">pauvrete</th>
#       <td>float64</td>
#       <td>Taux de pauvreté (compris entre 0 et 1)</td>
#       <td>Proportion de la population en dessous du seuil de pauvreté dans le département</td>
#     </tr>
#     <tr>
#       <th scope="row">aucun_diplome</th>
#       <td>float64</td>
#       <td>Proportion de la population totale</td>
#       <td>Proportion de la population totale ayant aucun diplôme dans le département</td>
#     </tr>
#     <tr>
#       <th scope="row">inf_bac</th>
#       <td>float64</td>
#       <td>Proportion de la population totale</td>
#       <td>Proportion de la population totale ayant un diplôme inférieur au baccalauréat dans le département</td>
#     </tr>
#     <tr>
#       <th scope="row">dipl_sup</th>
#       <td>float64</td>
#       <td>Proportion de la population totale</td>
#       <td>Proportion de la population totale diplômée du supérieur dans le département</td>
#     </tr>
#     <tr>
#       <th scope="row">sup_master</th>
#       <td>float64</td>
#       <td>Proportion de la population totale</td>
#       <td>Proportion de la population totale ayant un diplôme au moins équivalent au master dans le département</td>
#     </tr>
#     <tr>
#       <th scope="row">2019</th>
#       <td>float64</td>
#       <td>Nombre de bénéficiaires</td>
#       <td>Nombre d'utilisateurs du Pass Culture en 2019 dans le département</td>
#     </tr>
#     <tr>
#       <th scope="row">2020</th>
#       <td>float64</td>
#       <td>Nombre de bénéficiaires</td>
#       <td>Nombre d'utilisateurs du Pass Culture en 2020 dans le département</td>
#     </tr>
#     <tr>
#       <th scope="row">2021</th>
#       <td>float64</td>
#       <td>Nombre de bénéficiaires</td>
#       <td>Nombre d'utilisateurs du Pass Culture en 2021 dans le département</td>
#     </tr>
#     <tr>
#       <th scope="row">2022</th>
#       <td>float64</td>
#       <td>Nombre de bénéficiaires</td>
#       <td>Nombre d'utilisateurs du Pass Culture en 2022 dans le département</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Statistiques descriptives

# %%
carte_dep(df_final, "code_insee", "2021", "Blues", "Nombre de bénéficiaires du Pass en 2021")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 carte_dep(df_final, "code_insee", "2021", "Blues", "Nombre de bénéficiaires du Pass en 2021")
#
# NameError: name 'carte_dep' is not defined
